# %%
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
DATA_PATH = "data_aug.json"
SAVED_MODEL_PATH = "model_aug.h5"
EPOCHS = 25
BATCH_SIZE = 32
PATIENCE = 5
LEARNING_RATE = 0.0001

# %%
def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    print("Training sets loaded!")
    return X, y

# %%
def prepare_dataset(data_path, test_size=0.2, validation_size=0.2):
    # load dataset
    X, y = load_data(data_path)

    # create train, validation, test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to nd array
    X_train = X_train[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]

    return X_train, y_train, X_validation, y_validation, X_test, y_test

# %%
def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.0001):
    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape,
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 3rd conv layer
    model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))

    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    tf.keras.layers.Dropout(0.3)

    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    optimiser = tf.optimizers.Adam(learning_rate=learning_rate)

    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    # print model parameters on console
    model.summary()

    return model

# %%
def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    
    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation))
    return history

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="accuracy")
    axs[0].plot(history.history['val_accuracy'], label="val_accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create loss subplot
    axs[1].plot(history.history["loss"], label="loss")
    axs[1].plot(history.history['val_loss'], label="val_loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Loss evaluation")

    plt.show()

# %%
def main():
    # generate train, validation and test sets
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(DATA_PATH)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape, learning_rate=LEARNING_RATE)

    # train network
    history = train(model, EPOCHS, BATCH_SIZE, PATIENCE, X_train, y_train, X_validation, y_validation)

    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(history)

    # evaluate network on test set
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))

    # save model
    model.save(SAVED_MODEL_PATH)


if __name__ == "__main__":
    main()
# Out:
# Training sets loaded!
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 42, 11, 64)        640
#
#  batch_normalization_3 (Batc  (None, 42, 11, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 21, 6, 64)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 19, 4, 32)         18464
#
#  batch_normalization_4 (Batc  (None, 19, 4, 32)        128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 10, 2, 32)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 9, 1, 32)          4128
#
#  batch_normalization_5 (Batc  (None, 9, 1, 32)         128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 1, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 160)               0
#
#  dense_2 (Dense)             (None, 64)                10304
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 34,698
# Trainable params: 34,442
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/25
# 662/662 [==============================] - 6s 7ms/step - loss: 1.6370 - accuracy: 0.4933 - val_loss: 1.0425 - val_accuracy: 0.7209
# Epoch 2/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.7463 - accuracy: 0.8094 - val_loss: 0.6099 - val_accuracy: 0.8557
# Epoch 3/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.4869 - accuracy: 0.8857 - val_loss: 0.4502 - val_accuracy: 0.8998
# Epoch 4/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.3780 - accuracy: 0.9130 - val_loss: 0.3708 - val_accuracy: 0.9159
# Epoch 5/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.3091 - accuracy: 0.9334 - val_loss: 0.3103 - val_accuracy: 0.9310
# Epoch 6/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.2663 - accuracy: 0.9448 - val_loss: 0.2820 - val_accuracy: 0.9380
# Epoch 7/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.2339 - accuracy: 0.9536 - val_loss: 0.2638 - val_accuracy: 0.9452
# Epoch 8/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.2145 - accuracy: 0.9580 - val_loss: 0.2703 - val_accuracy: 0.9395
# Epoch 9/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.1961 - accuracy: 0.9640 - val_loss: 0.2577 - val_accuracy: 0.9442
# Epoch 10/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.1766 - accuracy: 0.9700 - val_loss: 0.2299 - val_accuracy: 0.9501
# Epoch 11/25
# 662/662 [==============================] - 4s 6ms/step - loss: 0.1686 - accuracy: 0.9710 - val_loss: 0.2202 - val_accuracy: 0.9531
# Epoch 12/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.1559 - accuracy: 0.9746 - val_loss: 0.1903 - val_accuracy: 0.9637
# Epoch 13/25
# 662/662 [==============================] - 5s 8ms/step - loss: 0.1480 - accuracy: 0.9762 - val_loss: 0.1880 - val_accuracy: 0.9660
# Epoch 14/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.1381 - accuracy: 0.9797 - val_loss: 0.1829 - val_accuracy: 0.9652
# Epoch 15/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1343 - accuracy: 0.9805 - val_loss: 0.1785 - val_accuracy: 0.9669
# Epoch 16/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1260 - accuracy: 0.9827 - val_loss: 0.1622 - val_accuracy: 0.9728
# Epoch 17/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1189 - accuracy: 0.9843 - val_loss: 0.1914 - val_accuracy: 0.9622
# Epoch 18/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1120 - accuracy: 0.9867 - val_loss: 0.1659 - val_accuracy: 0.9696
# Epoch 19/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.1094 - accuracy: 0.9864 - val_loss: 0.1508 - val_accuracy: 0.9767
# Epoch 20/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1121 - accuracy: 0.9848 - val_loss: 0.1410 - val_accuracy: 0.9790
# Epoch 21/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.0999 - accuracy: 0.9896 - val_loss: 0.1409 - val_accuracy: 0.9777
# Epoch 22/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.1019 - accuracy: 0.9882 - val_loss: 0.1503 - val_accuracy: 0.9741
# Epoch 23/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.0951 - accuracy: 0.9896 - val_loss: 0.1415 - val_accuracy: 0.9762
# Epoch 24/25
# 662/662 [==============================] - 4s 7ms/step - loss: 0.0901 - accuracy: 0.9914 - val_loss: 0.1464 - val_accuracy: 0.9735
# Epoch 25/25
# 662/662 [==============================] - 5s 7ms/step - loss: 0.0878 - accuracy: 0.9921 - val_loss: 0.1526 - val_accuracy: 0.9697
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1469 - accuracy: 0.9705
#
# Test loss: 0.146912083029747, test accuracy: 97.05081582069397
